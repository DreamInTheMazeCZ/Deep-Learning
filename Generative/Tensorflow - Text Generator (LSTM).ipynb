# %%
from __future__ import print_function
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, BatchNormalization
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.utils.data_utils import get_file

import numpy as np
import random, sys, io, warnings

warnings.filterwarnings('ignore')

random.seed(228)

# %%
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')

with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
    
print(f'텍스트 총 길이 : {len(text):,}개')
# Out:
# 텍스트 총 길이 : 600,893개

# %%
chars = sorted(set(text))

# %%
char_indices = {c:idx for idx, c in enumerate(chars)}
indices_char = {idx:c for idx, c in enumerate(chars)}

print(f'고유 텍스트 수 : {len(chars)}개')
# Out:
# 고유 텍스트 수 : 57개

# %%
# 텍스트를 maxlen 만큼의 집합으로 분리

maxlen = 40      # 추출할 텍스트 시퀀스의 최대값
step = 3         # 세 개의 텍스트씩 건너 새로운 시퀀스 생성

sentences = []   # 추출 시퀀스 컨테이너
next_chars = []  # 시퀀스 다음 글자(Target) 컨테이너

for idx in range(0, len(text) - maxlen, step): # idx = 0, 3, 6, ...
    sentences.append(text[idx: idx + maxlen])
    next_chars.append(text[idx + maxlen])
    
print(f'시퀀스의 총 개수 : {len(sentences):,}개')
# Out:
# 시퀀스의 총 개수 : 200,285개

# %%
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)  # (200285, 40, 57)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)          # (200285, 57)

# 문자를 이진수 배열로 벡터화

for sentences_idx, seperate_sentence in enumerate(sentences):
    for text_idx, char in enumerate(seperate_sentence):
        # x : 고유 텍스트가 존재하는 부분에 1
        x[sentences_idx, text_idx, char_indices[char]] = 1
    # y : Target의 고유 텍스트 1
    y[sentences_idx, char_indices[next_chars[sentences_idx]]] = 1

# %%
# LSTM 모델 정의

lstm_model = Sequential()

lstm_model.add(LSTM(256, input_shape=(maxlen, len(chars))))
lstm_model.add(Dense(128, activation='relu'))
lstm_model.add(Dropout(0.3))

lstm_model.add(BatchNormalization())
lstm_model.add(Dense(len(chars), activation='softmax'))

# %%
optimizer = Adam() # 오차역전파 최적화 함수
lstm_model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    '''
    모델의 예측값을 통해 새로운 글자를 샘플링하는 함수
    '''
    preds = np.asarray(preds).astype('float64') # 확률 분포 배열 추출
    preds = np.log(preds) / temperature         # 자연로그값 / 온도 (가중치 조절 분포 생성)
    exp_preds = np.exp(preds)                   # e ^ preds : 밑이 자연상수 e인 지수함수로 변환
    preds = exp_preds / np.sum(exp_preds)       # 무작위로 새로운 글자 샘플링
    probas = np.random.multinomial(n=1, pvals=preds, size=1)
    return np.argmax(probas)

# %%
start_index = random.randint(0, len(text) - maxlen - 1)
start_index
# Out:
# 154067

# %%
for epoch in range(1, 30): # 30 Epoch 훈련
    print(f'Epoch : {epoch}')
    lstm_model.fit(x, y, batch_size=64, epochs=1)            # 데이터에서 한 번만 반복해서 모델 학습
    
    seed_text = text[start_index: start_index + maxlen] # 무작위로 시드 텍스트를 선택한다.
    print(f'Seed Text : "{seed_text}"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:           # 여러 가지 샘플링 온도를 시도
        
        generated_text = seed_text
        sys.stdout.write(generated_text)
        
        for i in range(400): # 시드 텍스트에서 시작해서 400개의 글자 생성
            sampled = np.zeros((1, maxlen, len(chars)))  # One-Hot Encoding
            
            for text_idx, char in enumerate(generated_text): 
                sampled[0, text_idx, char_indices[char]] = 1.

            # 다음 글자를 샘플링
            preds = lstm_model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
        print(generated_text)
# Out:
# Epoch : 1
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8624
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gentanding and entire morality of a sort of
# o hostile and averse to the
# new; and gen cansafient man in short, perhaps it is
# o hostile and averse to the
# new; and gene and the general that is, is a crude to
# o hostile and averse to the
# new; and genan philosophy,
# and hers, also have feele
# Epoch : 2
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8546
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genll these species and so far as the stand
# o hostile and averse to the
# new; and gend and such a state of
# christianity than
# o hostile and averse to the
# new; and gener of forms be than it beywndance theref
# o hostile and averse to the
# new; and gen
# seems
# honest dequiofstealing, setsit, s
# Epoch : 3
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8512
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genbably makes itself these special these a
# o hostile and averse to the
# new; and geny, or enother turnified so denein more v
# o hostile and averse to the
# new; and gen the such psecise and , ma
# non--adas the
# o hostile and averse to the
# new; and genat now all the loven of reached with no
# Epoch : 4
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8500
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genand moral present, a strength of a sort
# o hostile and averse to the
# new; and gene notion of the forms of the common of t
# o hostile and averse to the
# new; and genlove for
# its
# greated help of it,
# in the
# o hostile and averse to the
# new; and gens attriated
# to fact that mare a of all s
# Epoch : 5
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8461
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gen their souls, that a comprehensive serio
# o hostile and averse to the
# new; and genrongest to falsification of everything t
# o hostile and averse to the
# new; and genis danger to pleasure therewish arised t
# o hostile and averse to the
# new; and genonferences, he is the individual but lon
# Epoch : 6
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8399
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genthe laws, that there is to be above all
# o hostile and averse to the
# new; and genoncealed was an art which man to conside
# o hostile and averse to the
# new; and genhich were
# more superficial voluntarily,
# o hostile and averse to the
# new; and gend by their gofless, justice now conduct,
# Epoch : 7
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.8381
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gene profound standard and rightens to the
# o hostile and averse to the
# new; and genn portination of our own bean forominal
# o hostile and averse to the
# new; and genreament more departion for his good
# noti
# o hostile and averse to the
# new; and gencivilization; and thereby such a balds o
# Epoch : 8
# 3130/3130 [==============================] - 58s 19ms/step - loss: 0.8327
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gen the present man stands to the standard
# o hostile and averse to the
# new; and genfoundly the worth of mankind, as a prese
# o hostile and averse to the
# new; and genrom their treating, but as knowed gate i
# o hostile and averse to the
# new; and genersonal sense,
# transciedless; btrives hi
# Epoch : 9
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.8296
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genlicate than it is also the self-delusion
# o hostile and averse to the
# new; and genall the political acts. the delicate mim
# o hostile and averse to the
# new; and gen of dequireform it is
# their general deve
# o hostile and averse to the
# new; and genthe incentive sfienting to the
# world
# nat
# Epoch : 10
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8276
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genkes a soul and bad and sensibility of th
# o hostile and averse to the
# new; and genhe pressive scientific
# spoken, and is mo
# o hostile and averse to the
# new; and genered, the body:--of the gradation of the
# o hostile and averse to the
# new; and gen more any the jesuits than the
# needs of
# Epoch : 11
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8238
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genlearned and moral concerning evil of an
# o hostile and averse to the
# new; and gen, in himself, the will to the world, and
# o hostile and averse to the
# new; and genr at least they are judged towards
# man:
# o hostile and averse to the
# new; and genkinds of man and more than as one
# of the
# Epoch : 12
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.8202
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genronger, as the subject, the strain parti
# o hostile and averse to the
# new; and genreatest entire from complays and can be
# o hostile and averse to the
# new; and genntinues in the ordinary
# less and
# femblif
# o hostile and averse to the
# new; and gencognize for such atraiinness at last sin
# Epoch : 13
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.8159
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genof more consciences of the strength of t
# o hostile and averse to the
# new; and gen and will and intercretess in the specta
# o hostile and averse to the
# new; and genpment of what this sagnified men in shor
# o hostile and averse to the
# new; and genally not already darements and he!" if a
# Epoch : 14
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8135
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genspecies of present presenting of the con
# o hostile and averse to the
# new; and gen most proceed of religious simple and so
# o hostile and averse to the
# new; and genectly, in the possibility of religious p
# o hostile and averse to the
# new; and genfor its borths,
# whatever bring printing,
# Epoch : 15
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8080
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genf the services of the conception of the
# o hostile and averse to the
# new; and gens. they are regarded to the condition fo
# o hostile and averse to the
# new; and genude.
#
# 199. the men of the
# eye.-cas for p
# o hostile and averse to the
# new; and gender to
# understand it: for instance, exti
# Epoch : 16
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.8066
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gent to the soul of the most delightful eve
# o hostile and averse to the
# new; and genether we way prove the contrary as a pre
# o hostile and averse to the
# new; and gent in the idea which the seer of mankind,
# o hostile and averse to the
# new; and genthought of to gain among the pra"se" and
# Epoch : 17
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.8024
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genall that is the anart and southert insti
# o hostile and averse to the
# new; and genesent sense and person with perhaps such
# o hostile and averse to the
# new; and gened, and is pleasure, what
# my weaker desi
# o hostile and averse to the
# new; and gent liverations with raght to your sympath
# Epoch : 18
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.7990
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gen sense, as the specialty in the senses a
# o hostile and averse to the
# new; and genthe proper as in the origin of this sain
# o hostile and averse to the
# new; and gen order to live one is to been consists e
# o hostile and averse to the
# new; and gentain
# thing our foll. it goated if they
# r
# Epoch : 19
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.7968
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gencious and and in the strange than the st
# o hostile and averse to the
# new; and genes of man all the person in every and pa
# o hostile and averse to the
# new; and gen
# dissimility it is deny
# for knowledge, e
# o hostile and averse to the
# new; and genon of the complete: and to man in that s
# Epoch : 20
# 3130/3130 [==============================] - 58s 19ms/step - loss: 0.7926
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and generion of the same and and the most self-
# o hostile and averse to the
# new; and geno the blood fight of man, with the sarni
# o hostile and averse to the
# new; and gen an exertions is untimilates, in its or
# o hostile and averse to the
# new; and genwer, it)--full to the gigneriin ou der n
# Epoch : 21
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.7925
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gench makes themselves have not regarded to
# o hostile and averse to the
# new; and genrded as we are not been doubt, the capac
# o hostile and averse to the
# new; and genine--as
# (the is hence for ourselves are
# o hostile and averse to the
# new; and gens
# we have amance to this
# little and woma
# Epoch : 22
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.7865
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gen the same helosification of the case of
# o hostile and averse to the
# new; and gen of our pains. a man of the struggle is
# o hostile and averse to the
# new; and gen of strange therewish thought calls the
# o hostile and averse to the
# new; and geno was preive--and how very
# rild, even wo
# Epoch : 23
# 3130/3130 [==============================] - 56s 18ms/step - loss: 0.7861
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genuch dispusts--mathelose, that the same t
# o hostile and averse to the
# new; and genendusive sade traditional manner also fo
# o hostile and averse to the
# new; and gens attencent.--but not dissimulation, per
# o hostile and averse to the
# new; and gen it is bewincting the exclante which the
# Epoch : 24
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.7816
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genperson is accustodised in the world, and
# o hostile and averse to the
# new; and gen crualiy, even to the consciousness of h
# o hostile and averse to the
# new; and generson  and
# the
# religious ne: for it, pai
# o hostile and averse to the
# new; and gend renouncing it
# all, he possecently, si-
# Epoch : 25
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.7785
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gens themselves have to men there is no dou
# o hostile and averse to the
# new; and genthe stake of the term who was betrayed t
# o hostile and averse to the
# new; and gened to be readed to
# the philosopher as wh
# o hostile and averse to the
# new; and genadual
# less in his own
# reference a person
# Epoch : 26
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.7765
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gen nother stands betrains all the experien
# o hostile and averse to the
# new; and gent is an an ascess and perperty, in the s
# o hostile and averse to the
# new; and gen believing things in the standard man es
# o hostile and averse to the
# new; and gent
# it is not extivated names of
# virtue,
# w
# Epoch : 27
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.7698
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and genout and states of the most delight in th
# o hostile and averse to the
# new; and genresents to the more vantonest prehand in
# o hostile and averse to the
# new; and genbase to a philosopher; ivolitaries, for
# o hostile and averse to the
# new; and gen, with their final recenture... we does
# Epoch : 28
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.7692
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gen, and the class of science of matters an
# o hostile and averse to the
# new; and genon of woman believe that is there respon
# o hostile and averse to the
# new; and gen what is
# opposite, from him in order to
# o hostile and averse to the
# new; and genmetter's
# chnethizal
# of man, for
# man
# and
# Epoch : 29
# 3130/3130 [==============================] - 57s 18ms/step - loss: 0.7676
# Seed Text : "o hostile and averse to the
# new; and gen"
# o hostile and averse to the
# new; and gen manifests itself speaking, no concealed
# o hostile and averse to the
# new; and gennd dangerous and marder of man, also, th
# o hostile and averse to the
# new; and genogial of his sufferer and described and
# o hostile and averse to the
# new; and gend of light, and scrult, it may nese able

# %%
generated_text
# Out:
# 'd of light, and scrult, it may nese able'

# %%
seed_text = ' you please take me so far away, you\'re ' # 임의의 영어
print(f'Seed Text : "{seed_text}"')

generated_text = seed_text

for i in range(600): # 시드 텍스트에서 시작해서 600개의 글자 생성
    sampled = np.zeros((1, maxlen, len(chars)))  # One-Hot Encoding

    for text_idx, char in enumerate(generated_text): 
        sampled[0, text_idx, char_indices[char]] = 1.

    # 다음 글자를 샘플링
    preds = lstm_model.predict(sampled, verbose=0)[0]
    next_index = sample(preds, 0.7)
    next_char = chars[next_index]

    generated_text += next_char
    generated_text = generated_text[1:]
    
print(f'Generated Text : {generated_text}')
# Out:
# Seed Text : " you please take me so far away, you're "
# Generated Text : itself the religious prise in indiness:-
